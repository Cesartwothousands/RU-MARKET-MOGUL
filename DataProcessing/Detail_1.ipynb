# %%
'''
# show meta information about the history (requires history() to be called first)
msft.recommendations
msft.recommendations_summary

msft.analyst_price_target
msft.revenue_forecasts
msft.earnings_forecasts
msft.earnings_trend
'''

'''
import yfinance as yf
data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")

yf.download(tickers = "SPY AAPL",  # list of tickers
            period = "1y",         # time period
            interval = "1d",       # trading interval
            prepost = False,       # download pre/post market hours data?
            repair = True)         # repair obvious price errors e.g. 100x?
'''
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 计算一个月前的日期
end_date = datetime.now() + timedelta(days=1)
start_date = end_date - timedelta(days=7)

# 下载AAPL股票数据
aapl = yf.download('AAPL', start=start_date, end=end_date, interval="1h")

# 绘制收盘价折线图
plt.figure(figsize=(14, 7))
plt.plot(aapl['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('AAPL Stock Price in the Last Month')
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 计算一个月前的日期
end_date = datetime.now()+timedelta(days=1)
start_date = end_date - timedelta(days=30)

# 获取AAPL股票对象
aapl = yf.Ticker('AAPL')

# 下载AAPL股票数据
aapl_history = aapl.history(start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'))
print(aapl_history)
# 绘制收盘价折线图
plt.figure(figsize=(14, 7))
plt.plot(aapl_history['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('AAPL Stock Price in the Last Month')
plt.grid()
plt.show()

# %%
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 计算一个月前的日期
end_date = datetime.now() + timedelta(days=1)
start_date = end_date - timedelta(days=30)

# 下载AAPL股票数据
aapl = yf.download('AAPL', start=start_date, end=end_date)
print(aapl)

# 绘制收盘价折线图
plt.figure(figsize=(14, 7))
plt.plot(aapl['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('AAPL Stock Price in the Last Month')
plt.grid()
plt.show()

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# 获取AAPL的价格数据
aapl = yf.Ticker("AAPL")

# 获取日范围的价格数据
day_prices = aapl.history(period="1d")

# 获取五日范围的价格数据
five_day_prices = aapl.history(period="5d")

# 获取月范围的价格数据
month_prices = aapl.history(period="1mo")

# 获取年范围的价格数据
year_prices = aapl.history(period="1y")

# 获取五年范围的价格数据
five_year_prices = aapl.history(period="5y")

# 绘制日范围的价格走势图
plt.plot(day_prices['Close'])
plt.title("AAPL Daily Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# 绘制五日范围的价格走势图
plt.plot(five_day_prices['Close'])
plt.title("AAPL 5-Day Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# 绘制月范围的价格走势图
plt.plot(month_prices['Close'])
plt.title("AAPL Monthly Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# 绘制年范围的价格走势图
plt.plot(year_prices['Close'])
plt.title("AAPL Yearly Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# 绘制五年范围的价格走势图
plt.plot(five_year_prices['Close'])
plt.title("AAPL 5-Year Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
day_prices
# Out:
#                                  Open        High         Low       Close
# Date
# 2023-04-17 00:00:00-04:00  165.089996  165.389999  164.029999  165.229996  \
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-04-17 00:00:00-04:00  38730570        0.0           0.0

# %%
five_day_prices

# %%
month_prices

# %%
year_prices

# %%
five_year_prices
